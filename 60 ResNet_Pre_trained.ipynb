# %%
from keras.applications.resnet50 import ResNet50
from keras.applications.resnet50 import preprocess_input
from keras.applications.resnet50 import decode_predictions
from keras.preprocessing.image import load_img, img_to_array
from keras.utils import plot_model
import numpy as np

# %%
img = load_img('trump.jpg')
img

# %%
type(img)

# %%
img_to_array(img)

# %%
img = img_to_array(img)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
img = cv2.resize(img, (224,224))
img = img.astype(np.uint8)
plt.imshow(img)

# %%
img.shape

# %%
img_pre = preprocess_input(img)

# %%
model = ResNet50()

# %%
result = model.predict(img_pre.reshape(1,224,224,3))

# %%
decode_predictions(result)

# %%
import PIL, urllib

# %%
url = 'https://cdn.libemaweb.com/f/151320/2560x1920/932633421b/luipaard-panter-tussen-struiken-safaripark-beekse-bergen.jpg'
img = PIL.Image.open(urllib.request.urlopen(url))
img = np.array(img)
img = cv2.resize(img, (224,224))
img = img.astype(np.uint8)
img_pre = preprocess_input(img)
result = model.predict(img_pre.reshape(1,224,224,3))
decode_predictions(result)

# %%
img

# %%
plot_model(model, show_layer_activations=True,
           show_layer_names=True, show_dtype=True,
           show_trainable=True, show_shapes=True)
