# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
# load the video 
vid = cv2.VideoCapture('images/nature.mp4')

# %%
vid
# Out:
# < cv2.VideoCapture 0x7d4eea8e3970>

# %%
ret, frame = vid.read()

# %%
ret
# Out:
# True

# %%
frame
# Out:
# array([[[ 48,  49,  44],
#         [ 41,  42,  37],
#         [ 38,  39,  34],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[ 43,  44,  39],
#         [ 37,  38,  33],
#         [ 32,  33,  28],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[ 40,  41,  36],
#         [ 36,  37,  32],
#         [ 30,  31,  26],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[ 32,  31,  25],
#         [ 26,  25,  19],
#         [ 26,  25,  19],
#         ...,
#         [ 27,  23,  19],
#         [ 27,  23,  19],
#         [ 28,  24,  20]],
#
#        [[ 32,  31,  25],
#         [ 26,  25,  19],
#         [ 26,  25,  19],
#         ...,
#         [ 27,  23,  19],
#         [ 27,  23,  19],
#         [ 28,  24,  20]],
#
#        [[ 32,  31,  25],
#         [ 26,  25,  19],
#         [ 26,  25,  19],
#         ...,
#         [ 27,  23,  19],
#         [ 27,  23,  19],
#         [ 28,  24,  20]]], dtype=uint8)

# %%
cv2.imshow('First Frame', frame)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Extract video metadata 
print('Width:', vid.get(cv2.CAP_PROP_FRAME_WIDTH))
print('Height:', vid.get(cv2.CAP_PROP_FRAME_HEIGHT))
print('Total Frames:', vid.get(cv2.CAP_PROP_FRAME_COUNT))
print('Frame Rate:', vid.get(cv2.CAP_PROP_FPS))
# Out:
# Width: 1270.0
# Height: 720.0
# Total Frames: 1409.0
# Frame Rate: 26.0

# %%
duration = vid.get(cv2.CAP_PROP_FRAME_COUNT) / vid.get(cv2.CAP_PROP_FPS)

# %%
duration
# Out:
# 54.19230769230769

# %% [markdown]
# #### Display the video

# %%
vid = cv2.VideoCapture('images/nature.mp4')

while True:
    ret, frame = vid.read()
    if ret == False:
        break
    cv2.imshow('My video', frame)
    if cv2.waitKey(20) == ord('q'): 
        break

cv2.destroyAllWindows()

# %%
cv2.imwrite('myframe.jpg', frame)
# Out:
# True

# %%
# Extract all the frames and store in folder /nature

# %%
vid = cv2.VideoCapture('images/nature.mp4')
i = 1
while True:
    ret, frame = vid.read()
    if ret == False:
        break
    cv2.imwrite('nature/image%d.jpg' %i, frame)
    i += 1

cv2.destroyAllWindows()
print('All frames saved!')
# Out:
# All frames saved!

# %%
# Extract the frame / image at 42 second 
time = '00:00:42.00'

# %%
hrs, mins, secs = time.split(':')

# %%
hrs, mins, secs
# Out:
# ('00', '00', '42.00')

# %%
fps = vid.get(cv2.CAP_PROP_FPS)

# %%
tframe = int(hrs) * 3600 * fps + int(mins) * 60 * fps + float(secs) * fps

# %%
tframe
# Out:
# 1092.0

# %%
vid.set(1, tframe)
# Out:
# True

# %%
ret, frame = vid.read()
cv2.imshow('Trigger Frame', frame)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #### Capture the video

# %%
vid = cv2.VideoCapture(0) 
vid.isOpened()
vid.release()
# Out:
# [ WARN:0@3048.310] global cap_v4l.cpp:999 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@3048.311] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range

# %%
vid.release()

# %%
vid = cv2.VideoCapture(0) 

frame_width = int(vid.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT))
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output.avi', fourcc, 30.0, (frame_width, frame_height))

while True:
    ret, frame = vid.read()
    out.write(frame)
    cv2.imshow('My Video', frame)
    if cv2.waitKey(5) == ord('q'): 
        break

vid.release()
out.release()
cv2.destroyAllWindows()
