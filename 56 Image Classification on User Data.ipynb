# %% [markdown]
# #### Dataset

# %%
# fruits.zip
# https://mitu.co.in/dataset

# %% [markdown]
# #### Import the libraries

# %%
from keras.models import Sequential
from keras.layers import Dense, Input, Conv2D, MaxPool2D, Flatten, Dropout
from keras.utils import plot_model, to_categorical
import cv2
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# #### Create the object of image data generators

# %%
train_datagen = ImageDataGenerator(rescale=1/255, zoom_range=0.2, 
                                  horizontal_flip=True, vertical_flip=True )

test_datagen = ImageDataGenerator(rescale=1/255)

# %% [markdown]
# #### Read the images

# %%
train = train_datagen.flow_from_directory(
    'datasets/fruits/dataset/training_set/',
    class_mode='binary', target_size=(64,64))
# Out:
# Found 13 images belonging to 2 classes.

# %%
train.filenames
# Out:
# ['apple/1.jpg',
#  'apple/2.jpeg',
#  'apple/3.jpeg',
#  'apple/4.jpeg',
#  'apple/5.jpg',
#  'apple/6.jpg',
#  'apple/7.jpg',
#  'orange/1.jpeg',
#  'orange/2.jpg',
#  'orange/3.jpeg',
#  'orange/4.jpeg',
#  'orange/5.jpg',
#  'orange/6.jpg']

# %%
train.class_indices
# Out:
# {'apple': 0, 'orange': 1}

# %%
test = test_datagen.flow_from_directory(
    'datasets/fruits/dataset/test_set/',
    class_mode='binary', target_size=(64,64))
# Out:
# Found 6 images belonging to 2 classes.

# %% [markdown]
# #### Build the model

# %%
model = Sequential()

model.add(Input(shape=(64,64,3)))

model.add(Conv2D(filters=16, kernel_size=(3,3), activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters=8, kernel_size=(3,3), activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# 2026-06-10 11:11:15.387722: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
model.compile(loss='binary_crossentropy', 
             optimizer='adam', metrics=['accuracy'])

# %%
model.fit(train, validation_data=test, epochs=10, batch_size=1)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9231 - loss: 0.6042 - val_accuracy: 1.0000 - val_loss: 0.5569
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 1.0000 - loss: 0.5476 - val_accuracy: 1.0000 - val_loss: 0.5299
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9231 - loss: 0.5422 - val_accuracy: 1.0000 - val_loss: 0.5008
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 1.0000 - loss: 0.5178 - val_accuracy: 1.0000 - val_loss: 0.4704
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 1.0000 - loss: 0.4689 - val_accuracy: 1.0000 - val_loss: 0.4361
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 1.0000 - loss: 0.4124 - val_accuracy: 1.0000 - val_loss: 0.3976
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.3724 - val_accuracy: 1.0000 - val_loss: 0.3632
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 1.0000 - loss: 0.3720 - val_accuracy: 1.0000 - val_loss: 0.3211
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 1.0000 - loss: 0.3384 - val_accuracy: 1.0000 - val_loss: 0.2794
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 1.0000 - loss: 0.2821 - val_accuracy: 1.0000 - val_loss: 0.2542

# %% [markdown]
# #### Prediction on new images

# %%
new1 = plt.imread('datasets/fruits/dataset/sample1.jpg')
new1 = cv2.resize(new1, (64, 64))
new1 = new1.reshape(1,64,64,3)
result = model.predict(new1, verbose=False)
if result[0][0] == 1:
    print('Orange')
else:
    print('Apple')
# Out:
# Orange

# %%
new1 = plt.imread('datasets/fruits/dataset/sample2.jpg')
new1 = cv2.resize(new1, (64, 64))
new1 = new1.reshape(1,64,64,3)
result = model.predict(new1, verbose=False)
if result[0][0] == 1:
    print('Orange')
else:
    print('Apple')
# Out:
# Apple
