# %% [markdown]
# #### install the libraries

# %%
pip install nltk spacy textblob -U
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /home/mitu/.local/lib/python3.10/site-packages (3.9.2)
# Collecting nltk
#   Downloading nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: spacy in /home/mitu/.local/lib/python3.10/site-packages (3.8.2)
# Collecting spacy
#   Downloading spacy-3.8.14-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (28 kB)
# Requirement already satisfied: textblob in /home/mitu/.local/lib/python3.10/site-packages (0.18.0.post0)
# Collecting textblob
#   Downloading textblob-0.20.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: click in /home/mitu/.local/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/mitu/.local/lib/python3.10/site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /home/mitu/.local/lib/python3.10/site-packages (from nltk) (4.67.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/mitu/.local/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/mitu/.local/lib/python3.10/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/mitu/.local/lib/python3.10/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/mitu/.local/lib/python3.10/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/mitu/.local/lib/python3.10/site-packages (from spacy) (3.0.9)
# Collecting thinc<8.4.0,>=8.3.12 (from spacy)
#   Downloading thinc-8.3.13-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/mitu/.local/lib/python3.10/site-packages (from spacy) (1.1.2)
# Collecting srsly<3.0.0,>=2.5.3 (from spacy)
#   Downloading srsly-2.5.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/mitu/.local/lib/python3.10/site-packages (from spacy) (2.0.10)
# Collecting weasel<2.0.0,>=1.0.0 (from spacy)
#   Downloading weasel-1.0.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting confection<2.0.0,>=1.3.2 (from spacy)
#   Downloading confection-1.3.3-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/mitu/.local/lib/python3.10/site-packages (from spacy) (0.9.4)
# Requirement already satisfied: numpy>=1.19.0 in /home/mitu/.local/lib/python3.10/site-packages (from spacy) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/mitu/.local/lib/python3.10/site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /home/mitu/.local/lib/python3.10/site-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy) (59.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (23.2)
# Requirement already satisfied: typing_extensions<5.0,>=4.0 in /home/mitu/.local/lib/python3.10/site-packages (from confection<2.0.0,>=1.3.2->spacy) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/mitu/.local/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/mitu/.local/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/mitu/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mitu/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.12.14)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.12->spacy)
#   Downloading blis-1.3.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (7.5 kB)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /home/mitu/.local/lib/python3.10/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: smart-open>=5.2.1 in /home/mitu/.local/lib/python3.10/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (6.4.0)
# Requirement already satisfied: httpx>=0.24.0 in /home/mitu/.local/lib/python3.10/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.27.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.2.0)
# Requirement already satisfied: httpcore==1.* in /home/mitu/.local/lib/python3.10/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/mitu/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.14.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.3)
# Downloading nltk-3.9.4-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 2.2 MB/s  0:00:00m 2.2 MB/s eta 0:00:01
# Downloading spacy-3.8.14-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (31.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.0/31.0 MB 1.7 MB/s  0:00:18 eta 0:00:010:00:01
# Downloading confection-1.3.3-py3-none-any.whl (35 kB)
# Downloading srsly-2.5.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 1.3 MB/s  0:00:001.5 MB/s eta 0:00:01:01
# Downloading thinc-8.3.13-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 1.7 MB/s  0:00:02m 1.7 MB/s eta 0:00:01
# Downloading blis-1.3.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 1.5 MB/s  0:00:07m 1.5 MB/s eta 0:00:01
# Downloading weasel-1.0.0-py3-none-any.whl (50 kB)
# Downloading textblob-0.20.0-py3-none-any.whl (624 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 625.0/625.0 kB 1.8 MB/s  0:00:00m ? eta -:--:--
# Installing collected packages: srsly, nltk, confection, blis, textblob, weasel, thinc, spacy
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.8
#     Uninstalling srsly-2.4.8:
#       Successfully uninstalled srsly-2.4.8
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.9.2
#     Uninstalling nltk-3.9.2:0m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/8 [nltk]
#       Successfully uninstalled nltk-3.9.2m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/8 [nltk]
#   Attempting uninstall: confection;5;237m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/8 [nltk]
#     Found existing installation: confection 0.1.4237m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/8 [nltk]
#     Uninstalling confection-0.1.4:37m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/8 [nltk]
#       Successfully uninstalled confection-0.1.45;237m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/8 [nltk]
#   Attempting uninstall: blis38;5;237m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/8 [nltk]
#     Found existing installation: blis 1.0.1━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/8 [nltk]
#     Uninstalling blis-1.0.1:━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━ 3/8 [blis]
#       Successfully uninstalled blis-1.0.15;237m╺━━━━━━━━━━━━━━━━━━━━━━━━ 3/8 [blis]
#   Attempting uninstall: textblob━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━ 3/8 [blis]
#     Found existing installation: textblob 0.18.0.post038;5;237m━━━━━━━━━━━━━━━━━━━━━━━━ 3/8 [blis]
#     Uninstalling textblob-0.18.0.post0:8;5;237m╺━━━━━━━━━━━━━━━━━━━━━━━━ 3/8 [blis]
#       Successfully uninstalled textblob-0.18.0.post0━━━━━━━━━━━━━━━━━━━━━━━━ 3/8 [blis]
#   Attempting uninstall: weasel━━╺━━━━━━━━━━━━━━━━━━━━━━━━ 3/8 [blis]
#     Found existing installation: weasel 0.3.47m╺━━━━━━━━━━━━━━━━━━━━━━━━ 3/8 [blis]
#     Uninstalling weasel-0.3.4:━━╺━━━━━━━━━━━━━━━━━━━━━━━━ 3/8 [blis]
#       Successfully uninstalled weasel-0.3.4237m╺━━━━━━━━━━━━━━━━━━━━━━━━ 3/8 [blis]
#   Attempting uninstall: thinc━━━╺━━━━━━━━━━━━━━━━━━━━━━━━ 3/8 [blis]
#     Found existing installation: thinc 8.3.237m╺━━━━━━━━━━━━━━━━━━━━━━━━ 3/8 [blis]
#     Uninstalling thinc-8.3.2:━━━╺━━━━━━━━━━━━━━━━━━━━━━━━ 3/8 [blis]
#       Successfully uninstalled thinc-8.3.2;237m╺━━━━━━━━━━━━━━━━━━━━━━━━ 3/8 [blis]
#   Attempting uninstall: spacy━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 6/8 [thinc]
#     Found existing installation: spacy 3.8.2━━━╺━━━━━━━━━ 6/8 [thinc]
#     Uninstalling spacy-3.8.2:━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━ 7/8 [spacy]
#       Successfully uninstalled spacy-3.8.2━━━━━━━━━━╺━━━━ 7/8 [spacy]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [spacy]m━━━━ 7/8 [spacy]
# Successfully installed blis-1.3.3 confection-1.3.3 nltk-3.9.4 spacy-3.8.14 srsly-2.5.3 textblob-0.20.0 thinc-8.3.13 weasel-1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
nltk.download('punkt')
nltk.download('punkt_tab')  # tokenization
nltk.download('stopwords')  # stopwords
nltk.download('averaged_perceptron_tagger')  # POS Tagging
nltk.download('averaged_perceptron_tagger_eng')  # POS Tagging
nltk.download('punkt')
nltk.download('wordnet')  # wordnet and lemmatization
nltk.download('indian')  # INDIAN POS Tagging
nltk.download('omw-1.4')  # multilinguial wordnet
# Out:
# [nltk_data] Downloading package punkt to /home/mitu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/mitu/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/mitu/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/mitu/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /home/mitu/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to /home/mitu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/mitu/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package indian to /home/mitu/nltk_data...
# [nltk_data]   Package indian is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/mitu/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# #### Sample Task

# %%
sent = 'They told that their ages are 24, 31 and 29 respectively.'
# Find the average of ages mentioned in this sentence

# %%
words = sent.split()
ages = []
for word in words:
    if word.isdigit(): 
        ages.append(int(word))

# %%
ages
# Out:
# [31, 29]

# %%
sum(ages) / len(ages)
# Out:
# 30.0

# %%
ages = [int(word) for word in sent.split() if word.isdigit()]

# %%
ages
# Out:
# [31, 29]

# %% [markdown]
# #### Word and sentence tokenizer

# %%
# import the tokenizer function
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
sent = '''Hello friends! How are you?
Welcome to the world of Python Programming.'''

# %%
print(sent)
# Out:
# Hello friends! How are you?
# Welcome to the world of Python Programming.

# %%
sents = sent_tokenize(sent)

# %%
sents
# Out:
# ['Hello friends!',
#  'How are you?',
#  'Welcome to the world of Python Programming.']

# %%
sents[0]
# Out:
# 'Hello friends!'

# %%
sents[1]
# Out:
# 'How are you?'

# %%
sents[2]
# Out:
# 'Welcome to the world of Python Programming.'

# %%
words = word_tokenize(sent)

# %%
words
# Out:
# ['Hello',
#  'friends',
#  '!',
#  'How',
#  'are',
#  'you',
#  '?',
#  'Welcome',
#  'to',
#  'the',
#  'world',
#  'of',
#  'Python',
#  'Programming',
#  '.']

# %%
# Among all tokens, find percentage of punctuation symbols in it

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
count_punct = 0
for word in word_tokenize(sent):
    if word in string.punctuation: 
        count_punct += 1

# %%
count_punct
# Out:
# 3

# %%
count_punct / len(word_tokenize(sent)) * 100
# Out:
# 20.0

# %%
sent
# Out:
# 'Hello friends! How are you?\nWelcome to the world of Python Programming.'

# %%
new_str = ''
for char in sent: 
    if char not in string.punctuation: 
        new_str += char

# %%
print(new_str)
# Out:
# Hello friends How are you
# Welcome to the world of Python Programming

# %%
str1 = '''पुणे हे भारताच्या दख्खन पठारावरील महाराष्ट्राचे एक महत्त्वाचे शहर आहे. पुणे जिल्ह्याचे आणि पुणे विभागाचे हे प्रशासकीय मुख्यालय आहे. २०११ जनगणनेनुसार, शहराच्या हद्दीतील ३.१ दशलक्ष लोकसंख्येसह पुणे हे भारतातील नववे सर्वात जास्त लोकसंख्या असलेले शहर आहे. महानगर प्रदेशातील ७.२ दशलक्ष रहिवासी लोकसंख्या आहे, यानुसार ते आठवे सर्वाधिक लोकसंख्या असलेले शहर आहे.[८] पुणे शहर पुणे महानगर प्रदेशाचा एक भाग आहे.[९] भारतातील सर्वात मोठ्या आयटी हबपैकी पुणे एक आहे.[१०][११] हे भारतातील सर्वात महत्वाचे ऑटोमोबाईल आणि उत्पादन केंद्रांपैकी एक आहे. पुणे हे एक विकसनशील शहर आहे.[१२] या शहराला येथील उच्च प्रतिष्ठित शैक्षणिक संस्थांमुळे "पूर्वेकडील ऑक्सफर्ड" म्हणून संबोधले जाते.[१३][१४][१५] "भारतातील सर्वात राहण्यायोग्य शहर" म्हणून अनेक वेळा पुण्याला स्थान देण्यात आले आहे. [१६][१७]
पुण्यावर राष्ट्रकूट राजघराणे, अहमदनगर सल्तनत, मुघल, आदिल शाही घराणे यांनी राज्य केले आहे. १८ व्या शतकात हे शहर मराठा साम्राज्याचा भाग होते, आणि मराठा साम्राज्याचे पंतप्रधान, पेशव्यांची हे आसन होते.[१८] पाताळेश्वर लेणी, शनिवारवाडा, शिंदे छत्री, विश्रामबाग वाडा यासारख्या अनेक ऐतिहासिक खुणा या कालखंडातील आहेत. वेगवेगळ्या कालखंडातील ऐतिहासिक स्थळे शहरभर पसरलेली आहेत.
'''

# %%
print(str1)
# Out:
# पुणे हे भारताच्या दख्खन पठारावरील महाराष्ट्राचे एक महत्त्वाचे शहर आहे. पुणे जिल्ह्याचे आणि पुणे विभागाचे हे प्रशासकीय मुख्यालय आहे. २०११ जनगणनेनुसार, शहराच्या हद्दीतील ३.१ दशलक्ष लोकसंख्येसह पुणे हे भारतातील नववे सर्वात जास्त लोकसंख्या असलेले शहर आहे. महानगर प्रदेशातील ७.२ दशलक्ष रहिवासी लोकसंख्या आहे, यानुसार ते आठवे सर्वाधिक लोकसंख्या असलेले शहर आहे.[८] पुणे शहर पुणे महानगर प्रदेशाचा एक भाग आहे.[९] भारतातील सर्वात मोठ्या आयटी हबपैकी पुणे एक आहे.[१०][११] हे भारतातील सर्वात महत्वाचे ऑटोमोबाईल आणि उत्पादन केंद्रांपैकी एक आहे. पुणे हे एक विकसनशील शहर आहे.[१२] या शहराला येथील उच्च प्रतिष्ठित शैक्षणिक संस्थांमुळे "पूर्वेकडील ऑक्सफर्ड" म्हणून संबोधले जाते.[१३][१४][१५] "भारतातील सर्वात राहण्यायोग्य शहर" म्हणून अनेक वेळा पुण्याला स्थान देण्यात आले आहे. [१६][१७]
# पुण्यावर राष्ट्रकूट राजघराणे, अहमदनगर सल्तनत, मुघल, आदिल शाही घराणे यांनी राज्य केले आहे. १८ व्या शतकात हे शहर मराठा साम्राज्याचा भाग होते, आणि मराठा साम्राज्याचे पंतप्रधान, पेशव्यांची हे आसन होते.[१८] पाताळेश्वर लेणी, शनिवारवाडा, शिंदे छत्री, विश्रामबाग वाडा यासारख्या अनेक ऐतिहासिक खुणा या कालखंडातील आहेत. वेगवेगळ्या कालखंडातील ऐतिहासिक स्थळे शहरभर पसरलेली आहेत.

# %%
word_tokenize(str1)
# Out:
# ['पुणे',
#  'हे',
#  'भारताच्या',
#  'दख्खन',
#  'पठारावरील',
#  'महाराष्ट्राचे',
#  'एक',
#  'महत्त्वाचे',
#  'शहर',
#  'आहे',
#  '.',
#  'पुणे',
#  'जिल्ह्याचे',
#  'आणि',
#  'पुणे',
#  'विभागाचे',
#  'हे',
#  'प्रशासकीय',
#  'मुख्यालय',
#  'आहे',
#  '.',
#  '२०११',
#  'जनगणनेनुसार',
#  ',',
#  'शहराच्या',
#  'हद्दीतील',
#  '३.१',
#  'दशलक्ष',
#  'लोकसंख्येसह',
#  'पुणे',
#  'हे',
#  'भारतातील',
#  'नववे',
#  'सर्वात',
#  'जास्त',
#  'लोकसंख्या',
#  'असलेले',
#  'शहर',
#  'आहे',
#  '.',
#  'महानगर',
#  'प्रदेशातील',
#  '७.२',
#  'दशलक्ष',
#  'रहिवासी',
#  'लोकसंख्या',
#  'आहे',
#  ',',
#  'यानुसार',
#  'ते',
#  'आठवे',
#  'सर्वाधिक',
#  'लोकसंख्या',
#  'असलेले',
#  'शहर',
#  'आहे',
#  '.',
#  '[',
#  '८',
#  ']',
#  'पुणे',
#  'शहर',
#  'पुणे',
#  'महानगर',
#  'प्रदेशाचा',
#  'एक',
#  'भाग',
#  'आहे',
#  '.',
#  '[',
#  '९',
#  ']',
#  'भारतातील',
#  'सर्वात',
#  'मोठ्या',
#  'आयटी',
#  'हबपैकी',
#  'पुणे',
#  'एक',
#  'आहे',
#  '.',
#  '[',
#  '१०',
#  ']',
#  '[',
#  '११',
#  ']',
#  'हे',
#  'भारतातील',
#  'सर्वात',
#  'महत्वाचे',
#  'ऑटोमोबाईल',
#  'आणि',
#  'उत्पादन',
#  'केंद्रांपैकी',
#  'एक',
#  'आहे',
#  '.',
#  'पुणे',
#  'हे',
#  'एक',
#  'विकसनशील',
#  'शहर',
#  'आहे',
#  '.',
#  '[',
#  '१२',
#  ']',
#  'या',
#  'शहराला',
#  'येथील',
#  'उच्च',
#  'प्रतिष्ठित',
#  'शैक्षणिक',
#  'संस्थांमुळे',
#  '``',
#  'पूर्वेकडील',
#  'ऑक्सफर्ड',
#  "''",
#  'म्हणून',
#  'संबोधले',
#  'जाते',
#  '.',
#  '[',
#  '१३',
#  ']',
#  '[',
#  '१४',
#  ']',
#  '[',
#  '१५',
#  ']',
#  '``',
#  'भारतातील',
#  'सर्वात',
#  'राहण्यायोग्य',
#  'शहर',
#  "''",
#  'म्हणून',
#  'अनेक',
#  'वेळा',
#  'पुण्याला',
#  'स्थान',
#  'देण्यात',
#  'आले',
#  'आहे',
#  '.',
#  '[',
#  '१६',
#  ']',
#  '[',
#  '१७',
#  ']',
#  'पुण्यावर',
#  'राष्ट्रकूट',
#  'राजघराणे',
#  ',',
#  'अहमदनगर',
#  'सल्तनत',
#  ',',
#  'मुघल',
#  ',',
#  'आदिल',
#  'शाही',
#  'घराणे',
#  'यांनी',
#  'राज्य',
#  'केले',
#  'आहे',
#  '.',
#  '१८',
#  'व्या',
#  'शतकात',
#  'हे',
#  'शहर',
#  'मराठा',
#  'साम्राज्याचा',
#  'भाग',
#  'होते',
#  ',',
#  'आणि',
#  'मराठा',
#  'साम्राज्याचे',
#  'पंतप्रधान',
#  ',',
#  'पेशव्यांची',
#  'हे',
#  'आसन',
#  'होते',
#  '.',
#  '[',
#  '१८',
#  ']',
#  'पाताळेश्वर',
#  'लेणी',
#  ',',
#  'शनिवारवाडा',
#  ',',
#  'शिंदे',
#  'छत्री',
#  ',',
#  'विश्रामबाग',
#  'वाडा',
#  'यासारख्या',
#  'अनेक',
#  'ऐतिहासिक',
#  'खुणा',
#  'या',
#  'कालखंडातील',
#  'आहेत',
#  '.',
#  'वेगवेगळ्या',
#  'कालखंडातील',
#  'ऐतिहासिक',
#  'स्थळे',
#  'शहरभर',
#  'पसरलेली',
#  'आहेत',
#  '.']

# %%
new_sent = 'Dr. Mrs. Kulkarni got 12 lakh rupees salary.'

# %%
word_tokenize(new_sent)
# Out:
# ['Dr.', 'Mrs.', 'Kulkarni', 'got', '12', 'lakh', 'rupees', 'salary', '.']

# %% [markdown]
# #### File operations

# %%
# Load the file mydata.txt and find average of numbers

# %%
f = open('mydata.txt')
data = f.read()

# %%
data = word_tokenize(data)

# %%
nums = []
for word in data:
    if not word.isalpha() and word not in string.punctuation: 
        nums.append(float(word))

# %%
sum(nums) / len(nums)
# Out:
# 9.345454545454546

# %%
nums
# Out:
# [12.0, 15.0, 10.0, 4.0, 9.0, 9.0, 12.0, 10.0, 4.5, 11.0, 6.3]

# %% [markdown]
# #### White Space Tokenizer

# %%
from nltk.tokenize import WhitespaceTokenizer

# %%
tk = WhitespaceTokenizer()

# %%
sent
# Out:
# 'Hello friends! How are you?\nWelcome to the world of Python Programming.'

# %%
tk.tokenize(sent)
# Out:
# ['Hello',
#  'friends!',
#  'How',
#  'are',
#  'you?',
#  'Welcome',
#  'to',
#  'the',
#  'world',
#  'of',
#  'Python',
#  'Programming.']

# %% [markdown]
# #### Space Tokenizer

# %%
from nltk.tokenize import SpaceTokenizer

# %%
tk = SpaceTokenizer()

# %%
tk.tokenize(sent)
# Out:
# ['Hello',
#  'friends!',
#  'How',
#  'are',
#  'you?\nWelcome',
#  'to',
#  'the',
#  'world',
#  'of',
#  'Python',
#  'Programming.']

# %%
sent = '''Hello friends! How are you?
Welcome\tto the world of Python\tProgramming.'''

# %%
print(sent)
# Out:
# Hello friends! How are you?
# Welcome	to the world of Python	Programming.

# %% [markdown]
# #### Tab Tokenizer

# %%
from nltk.tokenize import TabTokenizer

# %%
tk = TabTokenizer()

# %%
tk.tokenize(sent)
# Out:
# ['Hello friends! How are you?\nWelcome',
#  'to the world of Python',
#  'Programming.']

# %%
sent.split('\t')
# Out:
# ['Hello friends! How are you?\nWelcome',
#  'to the world of Python',
#  'Programming.']

# %% [markdown]
# #### Line Tokenizer

# %%
from nltk.tokenize import LineTokenizer

# %%
tk = LineTokenizer()

# %%
tk.tokenize(sent)
# Out:
# ['Hello friends! How are you?',
#  'Welcome\tto the world of Python\tProgramming.']

# %%
sent.split('\n')
# Out:
# ['Hello friends! How are you?',
#  'Welcome\tto the world of Python\tProgramming.']

# %% [markdown]
# #### Multi Word Expression Tokenizer

# %%
from nltk.tokenize import MWETokenizer

# %%
nsent = 'Chhatrapati Shivaji Maharaj was founder of Maratha empire'

# %%
word_tokenize(nsent)
# Out:
# ['Chhatrapati',
#  'Shivaji',
#  'Maharaj',
#  'was',
#  'founder',
#  'of',
#  'Maratha',
#  'empire']

# %%
mwe = MWETokenizer(separator=' ')

# %%
mwe.add_mwe(('Chhatrapati','Shivaji'))

# %%
mwe.tokenize(word_tokenize(nsent))
# Out:
# ['Chhatrapati Shivaji', 'Maharaj', 'was', 'founder', 'of', 'Maratha', 'empire']

# %% [markdown]
# #### Tweet Tokenizer

# %%
name = 'तुषार कुटे'

# %%
name
# Out:
# 'तुषार कुटे'

# %%
name.replace('ष','श')
# Out:
# 'तुशार कुटे'

# %%
name.startswith('त')
# Out:
# True

# %%
name.split()
# Out:
# ['तुषार', 'कुटे']

# %%
name.isascii()
# Out:
# False

# %%
name.index('र')
# Out:
# 4

# %%
char = '\u0915\u093E'
char
# Out:
# 'का'

# %%
char = '\u0041\u0073'
char
# Out:
# 'As'

# %%
ord('क')
# Out:
# 2325

# %%
chr(2354)
# Out:
# 'ल'

# %%
sent = 'Hello friends!:) How are you? Welcome to Python <3Programming.'

# %%
sent
# Out:
# 'Hello friends!:) How are you? Welcome to Python <3Programming.'

# %%
from nltk.tokenize import TweetTokenizer

# %%
tk = TweetTokenizer()

# %%
tk.tokenize(sent)
# Out:
# ['Hello',
#  'friends',
#  '!',
#  ':)',
#  'How',
#  'are',
#  'you',
#  '?',
#  'Welcome',
#  'to',
#  'Python',
#  '<3',
#  'Programming',
#  '.']

# %%
text = '😀'

# %%
print(text)
# Out:
# 😀

# %%
data = 'Hello friends👋 How are you?💥 Welcome to 🌎Python Programming.💻'

# %%
print(data)
# Out:
# Hello friends👋 How are you?💥 Welcome to 🌎Python Programming.💻

# %%
word_tokenize(data)
# Out:
# ['Hello',
#  'friends👋',
#  'How',
#  'are',
#  'you',
#  '?',
#  '💥',
#  'Welcome',
#  'to',
#  '🌎Python',
#  'Programming.💻']

# %%
tk.tokenize(data)
# Out:
# ['Hello',
#  'friends',
#  '👋',
#  'How',
#  'are',
#  'you',
#  '?',
#  '💥',
#  'Welcome',
#  'to',
#  '🌎',
#  'Python',
#  'Programming',
#  '.',
#  '💻']

# %% [markdown]
# #### Custom Tokenizer

# %%
import re

# %%
def custom_tokenizer(text):
    return re.split(r"[.,;?!\s]+", text)

text = "This is some text with punctuation > Let's tokenize it. Is it ok?"

# %%
custom_tokenizer(text)
# Out:
# ['This',
#  'is',
#  'some',
#  'text',
#  'with',
#  'punctuation',
#  '>',
#  "Let's",
#  'tokenize',
#  'it',
#  'Is',
#  'it',
#  'ok',
#  '']

# %%
class CommaTokenizer: 
    def tokeinze(self, text):
        return re.split(r"[,\s]+", text)

# %%
tk = CommaTokenizer()

# %%
fruits = 'apple, banana, cherry, pineapple.'

# %%
tk.tokeinze(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'pineapple.']
